# %% [markdown]
# ## Process downloaded line-ups

# %%
import glob
import json
import pandas as pd

line_ups = sorted(glob.glob("./lineups/*.json"))

all_apps_df = pd.DataFrame()
all_subs_df = pd.DataFrame()
all_sub_mins_df = pd.DataFrame()
all_yellows_df = pd.DataFrame()
all_reds_df = pd.DataFrame()

for line_up in line_ups:
    with open(line_up) as f:
        data = f.read()

    data = json.loads(data)
    try:
        event_id = data["event_id"]
    except:
        event_id = data[0]["event_id"]
        data = data[0]

    home_team = data["data"]["teams"]["homeTeam"]["name"]
    away_team = data["data"]["teams"]["awayTeam"]["name"]

    if home_team == "Tranmere Rovers":
        team = 'homeTeam'
    else:
        team = 'awayTeam'

    formation = data["data"]["teams"][team]["formation"]
    formation = "-".join(str(formation))

    players = data["data"]["teams"][team]["players"]

    apps_df = pd.DataFrame()
    cards_df = pd.DataFrame()
    subs_df = pd.DataFrame()
    sub_mins_df = pd.DataFrame()

    for player in players:
        player_name = player["name"]["full"]
        try:
            shirt_no = player["meta"]["uniformNumber"]
        except:
            shirt_no = None
        role = player["meta"]["status"].replace("bench", "sub")
        
        player_app = {
            "event_id": event_id,
            "player_name": player_name,
            "shirt_no": shirt_no,
            "role": role
        }
        player_app = pd.DataFrame(player_app, index = [0])

        apps_df = pd.concat([apps_df, player_app], axis = 0)

        cards = player["bookings"]
        if cards:
            player_cards = pd.json_normalize(player["bookings"])
            player_cards["event_id"] = event_id
            player_cards["player_name"] = player_name
            cards_df = pd.concat([cards_df, player_cards], axis = 0)

        subs = player["substitutions"]
        if subs:
            sub_min = subs[0]["timeElapsed"]
            try:
                sub_on_no = subs[0]["replacedBy"]["meta"]["uniformNumber"]
            except:
                sub_on_no = None
            player_on = subs[0]["replacedBy"]["name"]["full"]
            sub_mins_pld = subs[0]["timeElapsed"]
            sub_mins = [{
                "event_id": event_id,
                "player_name": player_name,
                "min_off": sub_min,
                "min_on": ""
            },
            {
                "event_id": event_id,
                "player_name": player_on,
                "min_off": "",
                "min_on": sub_min
            }]
            sub_mins = pd.DataFrame(sub_mins)
            sub_mins_df = pd.concat([sub_mins_df, sub_mins], axis = 0)

            sub_names = [{
                "event_id": event_id,
                "shirt_no": sub_on_no,
                "player_name": player_name,
                "on_for": shirt_no,
                "off_for": ""
            },
            {
                "event_id": event_id,
                "shirt_no": shirt_no,
                "player_name": player_on,
                "on_for": "",
                "off_for": sub_on_no
            }]
            sub_names = pd.DataFrame(sub_names)
            subs_df = pd.concat([subs_df, sub_names], axis = 0)
    
    all_apps_df = pd.concat([all_apps_df, apps_df], axis = 0)
    all_subs_df = pd.concat([all_subs_df, subs_df], axis = 0)
    all_sub_mins_df = pd.concat([all_sub_mins_df, sub_mins_df], axis = 0)

    if not cards_df.empty:
        yellows_df = cards_df.query("type == 'yellow-card'")
        reds_df = cards_df.query("type.str.contains('red')")
        if not yellows_df.empty:
            yellows_df = yellows_df[["event_id", "player_name"]]
            yellows_df["yellow_card"] = 1
            all_yellows_df = pd.concat([all_yellows_df, yellows_df], axis = 0)
        if not reds_df.empty:
            reds_df = reds_df[["event_id", "player_name", "timeElapsed"]].rename(columns = {"timeElapsed": "min_so"})
            all_reds_df = pd.concat([all_reds_df, reds_df], axis = 0)

# ALL REQUIRE GAME DATE
# all_subs_df
# all_sub_mins_df
# all_yellows_df
# all_reds_df

# %% [markdown]
# ## Process downloaded match data

# %%
import glob
import json
import pandas as pd
import re

all_months_json = sorted(glob.glob("./matches/*.json"))

all_match_records = []
for month_json in all_months_json:
        with open(month_json) as f:
                data = f.read()

        data = json.loads(data)

        comps = data["payload"][0]["body"]["matchData"]

        for comp in comps:
                comp_data = comp["tournamentMeta"]

                match_keys = comp["tournamentDatesWithEvents"].keys()

                for match_key in match_keys:
                        match = comp["tournamentDatesWithEvents"][match_key][0]

                        cup_data = match["round"]

                        match_data = match["events"][0]

                        event_id = match_data["eventKey"]

                        if match_data["eventStatus"] != "post-event":
                                next
                        elif comp_data["tournamentName"]["first"] == "Friendly Match":
                                next
                        else:
                                if match_data["homeTeam"]["name"]["full"] == "Tranmere Rovers":
                                        tranmere = "homeTeam"
                                        opponent = "awayTeam"
                                else:
                                        tranmere = "awayTeam"
                                        opponent = "homeTeam"
                                
                                game_date = match_data["startTime"][:10]
                                print(game_date)

                                opposition = match_data[opponent]["name"]["full"]

                                if match_data["venue"]["name"]["full"] == "Wembley Stadium":
                                        venue = "N"
                                elif match_data["venue"]["name"]["full"] == "Prenton Park":
                                        venue = "H"
                                elif match_data["venue"]["name"]["full"] != "Prenton Park":
                                        venue = "A"

                                goals_for = match_data[tranmere]["scores"]["score"]

                                goals_against = match_data[opponent]["scores"]["score"]

                                score = f"{goals_for}-{goals_against}"

                                if goals_for > goals_against:
                                        outcome = "W"
                                elif goals_for < goals_against:
                                        outcome = "L"
                                else:
                                        outcome = "D"

                                goal_diff = goals_for - goals_against

                                if comp_data["tournamentName"]["first"] in ["League One", "League Two", "National League"]:
                                        if "round" not in cup_data:
                                                game_type = "League"
                                        else:
                                                if "Play-offs" in cup_data["round"]["full"]:
                                                        game_type = "League Play-Off"     
                                else:
                                        game_type = "Cup"

                                competition = comp_data["tournamentName"]["full"]

                                ko_time = match_data["startTimeInUKHHMM"]

                                event_type = match_data["eventType"]
                                if event_type:
                                        if " leg" in event_type:
                                                cup_leg = event_type[:1]

                                        if event_type.upper() == "REPLAY":
                                                cup_replay = 1
                                else:
                                        cup_leg = None
                                        cup_replay = None

                                cup_name = cup_data["name"]
                                if cup_name:
                                        # if "full" in cup_data["name"]:
                                        cup_stage = cup_data["name"]["full"]
                                        if re.search(r"North(?:ern)?", cup_stage):
                                                cup_section = re.search(r"North(?:ern)?", cup_stage).group(0)
                                else:
                                        cup_stage = None
                                        cup_section = None

                                if match_data["eventProgress"] == "EXTRATIMECOMPLETE":
                                        aet = 1
                                else:
                                        aet = None

                                pen_gf = match_data[tranmere]["scores"]["shootout"]

                                pen_ga = match_data[opponent]["scores"]["shootout"]

                                if pen_gf:
                                        if pen_gf > pen_ga:
                                                pen_outcome = "W"
                                        elif pen_gf < pen_ga:
                                                pen_outcome = "L"
                                else:
                                        pen_outcome = None

                                pen_score = f"{pen_gf}-{pen_ga}"

                                agg_gf = match_data[tranmere]["scores"]["aggregate"]

                                agg_ga = match_data[opponent]["scores"]["aggregate"]

                                agg_outcome = None
                                if agg_gf:
                                        if agg_gf > agg_ga:
                                                agg_outcome = "W"
                                        elif agg_gf < agg_ga:
                                                agg_outcome = "L"
                                        else:
                                                agg_outcome = "D"

                                agg_score = None
                                if agg_outcome:
                                        agg_score = f"{agg_gf}-{agg_ga}"

                                decider = match_data["eventOutcomeType"]
                                if decider == "shootout":
                                        decider = "pens"
                                if decider == "extra-time":
                                        decider = "extra time"

                                if aet or pen_outcome or agg_outcome:
                                        cup_outcome = match_data[tranmere]["eventOutcome"].upper()[:1]
                                else:
                                        cup_outcome = None

                                if pen_outcome and agg_outcome:
                                        if pen_outcome == "W":
                                                str_outcome = "Won"
                                        else:
                                                str_outcome = "Lost"
                                        outcome_desc = f"{agg_score}. {str_outcome} {pen_score} on pens"
                                elif pen_outcome and not agg_outcome:
                                        if pen_outcome == "W":
                                                str_outcome = "Won"
                                        else:
                                                str_outcome = "Lost"
                                        outcome_desc = f"{str_outcome} {pen_score} on pens"
                                elif agg_outcome and not pen_outcome:
                                        if agg_outcome == "W":
                                                str_outcome = "Won"
                                        else:
                                                str_outcome = "Lost"
                                        outcome_desc = f"{str_outcome} {agg_score} on agg"
                                else:
                                        outcome_desc = None

                                if aet == 1:
                                        game_length = 120
                                else:
                                        game_length = 90

                                stadium = match_data["venue"]["name"]["full"]

                                match_record = {
                                        "game_date": game_date,
                                        "opposition": opposition,
                                        "venue": venue,
                                        "goals_for": goals_for,
                                        "goals_against": goals_against,
                                        "score": score,
                                        "outcome": outcome,
                                        "goal_diff": goal_diff,
                                        "game_type": game_type,
                                        "competition": competition,
                                        "ko_time": ko_time,
                                        "cup_leg": cup_leg,
                                        "cup_stage": cup_stage,
                                        "cup_replay": cup_replay,
                                        "cup_section": cup_section,
                                        "aet": aet,
                                        "pen_gf": pen_gf,
                                        "pen_ga": pen_ga,
                                        "pen_outcome": pen_outcome,
                                        "pen_score": pen_score,
                                        "agg_gf": agg_gf,
                                        "agg_ga": agg_ga,
                                        "agg_outcome": agg_outcome,
                                        "agg_score": agg_score,
                                        "decider": decider,
                                        "cup_outcome": cup_outcome,
                                        "outcome_desc": outcome_desc,
                                        "game_length": game_length,
                                        "stadium": stadium,
                                        "event_id": event_id
                                }
                                all_match_records.append(match_record)
                        
                                filename = f"./matches/match-data/{event_id}.json"
                                with open(filename, "w") as outfile:
                                        json.dump(match, outfile)
                                        print(f"Saved data to {filename}" )

matches_df = pd.DataFrame(all_match_records)
# Out:
# 2011-08-06
# Saved data to ./matches/match-data/EFBO361411.json
# 2011-08-13
# Saved data to ./matches/match-data/EFBO361420.json
# 2011-08-16
# Saved data to ./matches/match-data/EFBO361433.json
# 2011-08-20
# Saved data to ./matches/match-data/EFBO361447.json
# 2011-08-27
# Saved data to ./matches/match-data/EFBO361451.json
# 2011-08-30
# Saved data to ./matches/match-data/EFBO381822.json
# 2011-09-03
# Saved data to ./matches/match-data/EFBO361471.json
# 2011-09-10
# Saved data to ./matches/match-data/EFBO361479.json
# 2011-09-13
# Saved data to ./matches/match-data/EFBO361495.json
# 2011-09-17
# Saved data to ./matches/match-data/EFBO361507.json
# 2011-09-24
# Saved data to ./matches/match-data/EFBO361518.json
# 2011-10-01
# Saved data to ./matches/match-data/EFBO361531.json
# 2011-10-01
# Saved data to ./matches/match-data/EFBO361531.json
# 2011-10-08
# Saved data to ./matches/match-data/EFBO361537.json
# 2011-10-12
# Saved data to ./matches/match-data/EFBO419418.json
# 2011-10-15
# Saved data to ./matches/match-data/EFBO361555.json
# 2011-10-22
# Saved data to ./matches/match-data/EFBO361569.json
# 2011-10-25
# Saved data to ./matches/match-data/EFBO361574.json
# 2011-10-29
# Saved data to ./matches/match-data/EFBO361589.json
# 2011-11-05
# Saved data to ./matches/match-data/EFBO361605.json
# 2011-11-09
# Saved data to ./matches/match-data/EFBO420035.json
# 2011-11-19
# Saved data to ./matches/match-data/EFBO361614.json
# 2011-11-26
# Saved data to ./matches/match-data/EFBO361623.json
# 2011-12-10
# Saved data to ./matches/match-data/EFBO361638.json
# 2011-12-17
# Saved data to ./matches/match-data/EFBO361653.json
# 2011-12-30
# Saved data to ./matches/match-data/EFBO361674.json
# 2012-01-02
# Saved data to ./matches/match-data/EFBO361688.json
# 2012-01-07
# Saved data to ./matches/match-data/EFBO361699.json
# 2012-01-14
# Saved data to ./matches/match-data/EFBO361713.json
# 2012-01-17
# Saved data to ./matches/match-data/EFBO361662.json
# 2012-01-21
# Saved data to ./matches/match-data/EFBO361714.json
# 2012-01-28
# Saved data to ./matches/match-data/EFBO361735.json
# 2012-02-04
# Saved data to ./matches/match-data/EFBO361749.json
# 2012-02-14
# Saved data to ./matches/match-data/EFBO361764.json
# 2012-02-18
# Saved data to ./matches/match-data/EFBO361783.json
# 2012-02-25
# Saved data to ./matches/match-data/EFBO361793.json
# 2012-03-03
# Saved data to ./matches/match-data/EFBO361800.json
# 2012-03-06
# Saved data to ./matches/match-data/EFBO361819.json
# 2012-03-10
# Saved data to ./matches/match-data/EFBO361831.json
# 2012-03-13
# Saved data to ./matches/match-data/EFBO361759.json
# 2012-03-17
# Saved data to ./matches/match-data/EFBO361844.json
# 2012-03-20
# Saved data to ./matches/match-data/EFBO361855.json
# 2012-03-24
# Saved data to ./matches/match-data/EFBO361866.json
# 2012-03-31
# Saved data to ./matches/match-data/EFBO361871.json
# 2012-04-06
# Saved data to ./matches/match-data/EFBO361890.json
# 2012-04-09
# Saved data to ./matches/match-data/EFBO361901.json
# 2012-04-14
# Saved data to ./matches/match-data/EFBO361915.json
# 2012-04-21
# Saved data to ./matches/match-data/EFBO361929.json
# 2012-04-28
# Saved data to ./matches/match-data/EFBO361933.json
# 2012-05-05
# Saved data to ./matches/match-data/EFBO361953.json
# 2012-08-18
# Saved data to ./matches/match-data/EFBO443518.json
# 2012-08-21
# Saved data to ./matches/match-data/EFBO443523.json
# 2012-08-25
# Saved data to ./matches/match-data/EFBO443543.json
# 2012-09-01
# Saved data to ./matches/match-data/EFBO443554.json
# 2012-09-01
# Saved data to ./matches/match-data/EFBO443554.json
# 2012-09-04
# Saved data to ./matches/match-data/EFBO472824.json
# 2012-09-08
# Saved data to ./matches/match-data/EFBO443561.json
# 2012-09-15
# Saved data to ./matches/match-data/EFBO443580.json
# 2012-09-18
# Saved data to ./matches/match-data/EFBO443592.json
# 2012-09-22
# Saved data to ./matches/match-data/EFBO443596.json
# 2012-09-29
# Saved data to ./matches/match-data/EFBO443616.json
# 2012-10-02
# Saved data to ./matches/match-data/EFBO443625.json
# 2012-10-06
# Saved data to ./matches/match-data/EFBO443636.json
# 2012-10-13
# Saved data to ./matches/match-data/EFBO443652.json
# 2012-10-20
# Saved data to ./matches/match-data/EFBO443653.json
# 2012-10-23
# Saved data to ./matches/match-data/EFBO443676.json
# 2012-10-27
# Saved data to ./matches/match-data/EFBO443688.json
# 2012-11-07
# Saved data to ./matches/match-data/EFBO443693.json
# 2012-11-10
# Saved data to ./matches/match-data/EFBO443709.json
# 2012-11-13
# Saved data to ./matches/match-data/EFBO481014.json
# 2012-11-16
# Saved data to ./matches/match-data/EFBO443724.json
# 2012-11-20
# Saved data to ./matches/match-data/EFBO443736.json
# 2012-11-24
# Saved data to ./matches/match-data/EFBO443746.json
# 2012-12-08
# Saved data to ./matches/match-data/EFBO443759.json
# 2012-12-15
# Saved data to ./matches/match-data/EFBO443769.json
# 2012-12-21
# Saved data to ./matches/match-data/EFBO443782.json
# 2012-12-26
# Saved data to ./matches/match-data/EFBO443796.json
# 2012-12-29
# Saved data to ./matches/match-data/EFBO443808.json
# 2013-01-01
# Saved data to ./matches/match-data/EFBO443810.json
# 2013-01-01
# Saved data to ./matches/match-data/EFBO443810.json
# 2013-01-12
# Saved data to ./matches/match-data/EFBO443844.json
# 2013-01-16
# Saved data to ./matches/match-data/EFBO443823.json
# 2013-01-19
# Saved data to ./matches/match-data/EFBO443845.json
# 2013-02-02
# Saved data to ./matches/match-data/EFBO443878.json
# 2013-02-09
# Saved data to ./matches/match-data/EFBO443887.json
# 2013-02-15
# Saved data to ./matches/match-data/EFBO443902.json
# 2013-02-19
# Saved data to ./matches/match-data/EFBO443868.json
# 2013-02-23
# Saved data to ./matches/match-data/EFBO443908.json
# 2013-02-26
# Saved data to ./matches/match-data/EFBO443928.json
# 2013-03-02
# Saved data to ./matches/match-data/EFBO443940.json
# 2013-03-09
# Saved data to ./matches/match-data/EFBO443952.json
# 2013-03-12
# Saved data to ./matches/match-data/EFBO443963.json
# 2013-03-16
# Saved data to ./matches/match-data/EFBO443971.json
# 2013-03-24
# Saved data to ./matches/match-data/EFBO443988.json
# 2013-03-29
# Saved data to ./matches/match-data/EFBO443999.json
# 2013-04-01
# Saved data to ./matches/match-data/EFBO444008.json
# 2013-04-01
# Saved data to ./matches/match-data/EFBO444008.json
# 2013-04-06
# Saved data to ./matches/match-data/EFBO444016.json
# 2013-04-13
# Saved data to ./matches/match-data/EFBO444036.json
# 2013-04-20
# Saved data to ./matches/match-data/EFBO444045.json
# 2013-04-27
# Saved data to ./matches/match-data/EFBO444060.json
# 2013-08-03
# Saved data to ./matches/match-data/EFBO695845.json
# 2013-08-06
# Saved data to ./matches/match-data/EFBO694867.json
# 2013-08-10
# Saved data to ./matches/match-data/EFBO695856.json
# 2013-08-17
# Saved data to ./matches/match-data/EFBO695861.json
# 2013-08-24
# Saved data to ./matches/match-data/EFBO695880.json
# 2013-08-27
# Saved data to ./matches/match-data/EFBO720114.json
# 2013-08-31
# Saved data to ./matches/match-data/EFBO695886.json
# 2013-09-03
# Saved data to ./matches/match-data/EFBO722077.json
# 2013-09-07
# Saved data to ./matches/match-data/EFBO695904.json
# 2013-09-14
# Saved data to ./matches/match-data/EFBO695916.json
# 2013-09-21
# Saved data to ./matches/match-data/EFBO695921.json
# 2013-09-25
# Saved data to ./matches/match-data/EFBO726613.json
# 2013-09-28
# Saved data to ./matches/match-data/EFBO695940.json
# 2013-10-05
# Saved data to ./matches/match-data/EFBO695952.json
# 2013-10-13
# Saved data to ./matches/match-data/EFBO695954.json
# 2013-10-19
# Saved data to ./matches/match-data/EFBO695975.json
# 2013-10-22
# Saved data to ./matches/match-data/EFBO695986.json
# 2013-10-26
# Saved data to ./matches/match-data/EFBO696000.json
# 2013-11-02
# Saved data to ./matches/match-data/EFBO696009.json
# 2013-11-09
# Saved data to ./matches/match-data/EFBO732265.json
# 2013-11-16
# Saved data to ./matches/match-data/EFBO696024.json
# 2013-11-23
# Saved data to ./matches/match-data/EFBO696027.json
# 2013-11-26
# Saved data to ./matches/match-data/EFBO696049.json
# 2013-11-30
# Saved data to ./matches/match-data/EFBO696060.json
# 2013-12-07
# Saved data to ./matches/match-data/EFBO732765.json
# 2013-12-14
# Saved data to ./matches/match-data/EFBO696065.json
# 2013-12-20
# Saved data to ./matches/match-data/EFBO696084.json
# 2013-12-26
# Saved data to ./matches/match-data/EFBO696096.json
# 2013-12-29
# Saved data to ./matches/match-data/EFBO696107.json
# 2014-01-01
# Saved data to ./matches/match-data/EFBO696120.json
# 2014-01-01
# Saved data to ./matches/match-data/EFBO696120.json
# 2014-01-11
# Saved data to ./matches/match-data/EFBO696144.json
# 2014-01-18
# Saved data to ./matches/match-data/EFBO696151.json
# 2014-01-25
# Saved data to ./matches/match-data/EFBO696168.json
# 2014-01-28
# Saved data to ./matches/match-data/EFBO696180.json
# 2014-02-01
# Saved data to ./matches/match-data/EFBO696187.json
# 2014-02-01
# Saved data to ./matches/match-data/EFBO696187.json
# 2014-02-08
# Saved data to ./matches/match-data/EFBO696204.json
# 2014-02-15
# Saved data to ./matches/match-data/EFBO696206.json
# 2014-02-22
# Saved data to ./matches/match-data/EFBO696228.json
# 2014-03-01
# Saved data to ./matches/match-data/EFBO696240.json
# 2014-03-01
# Saved data to ./matches/match-data/EFBO696240.json
# 2014-03-08
# Saved data to ./matches/match-data/EFBO696251.json
# 2014-03-11
# Saved data to ./matches/match-data/EFBO696254.json
# 2014-03-15
# Saved data to ./matches/match-data/EFBO696276.json
# 2014-03-22
# Saved data to ./matches/match-data/EFBO696284.json
# 2014-03-25
# Saved data to ./matches/match-data/EFBO696300.json
# 2014-03-29
# Saved data to ./matches/match-data/EFBO696312.json
# 2014-04-05
# Saved data to ./matches/match-data/EFBO696318.json
# 2014-04-12
# Saved data to ./matches/match-data/EFBO696336.json
# 2014-04-15
# Saved data to ./matches/match-data/EFBO696124.json
# 2014-04-18
# Saved data to ./matches/match-data/EFBO696345.json
# 2014-04-21
# Saved data to ./matches/match-data/EFBO696360.json
# 2014-04-26
# Saved data to ./matches/match-data/EFBO696367.json
# 2014-05-03
# Saved data to ./matches/match-data/EFBO696383.json
# 2014-08-09
# Saved data to ./matches/match-data/EFBO756798.json
# 2014-08-12
# Saved data to ./matches/match-data/EFBO754351.json
# 2014-08-16
# Saved data to ./matches/match-data/EFBO756807.json
# 2014-08-19
# Saved data to ./matches/match-data/EFBO756821.json
# 2014-08-23
# Saved data to ./matches/match-data/EFBO756834.json
# 2014-08-30
# Saved data to ./matches/match-data/EFBO756845.json
# 2014-09-06
# Saved data to ./matches/match-data/EFBO756847.json
# 2014-09-13
# Saved data to ./matches/match-data/EFBO756864.json
# 2014-09-16
# Saved data to ./matches/match-data/EFBO756881.json
# 2014-09-20
# Saved data to ./matches/match-data/EFBO756893.json
# 2014-09-27
# Saved data to ./matches/match-data/EFBO756897.json
# 2014-10-04
# Saved data to ./matches/match-data/EFBO756908.json
# 2014-10-07
# Saved data to ./matches/match-data/EFBO783313.json
# 2014-10-11
# Saved data to ./matches/match-data/EFBO756930.json
# 2014-10-18
# Saved data to ./matches/match-data/EFBO756937.json
# 2014-10-21
# Saved data to ./matches/match-data/EFBO756954.json
# 2014-10-25
# Saved data to ./matches/match-data/EFBO756955.json
# 2014-11-01
# Saved data to ./matches/match-data/EFBO756978.json
# 2014-11-01
# Saved data to ./matches/match-data/EFBO756978.json
# 2014-11-08
# Saved data to ./matches/match-data/EFBO785977.json
# 2014-11-11
# Saved data to ./matches/match-data/EFBO785287.json
# 2014-11-15
# Saved data to ./matches/match-data/EFBO756982.json
# 2014-11-22
# Saved data to ./matches/match-data/EFBO757002.json
# 2014-11-29
# Saved data to ./matches/match-data/EFBO757014.json
# 2014-12-06
# Saved data to ./matches/match-data/EFBO786750.json
# 2014-12-09
# Saved data to ./matches/match-data/EFBO786857.json
# 2014-12-13
# Saved data to ./matches/match-data/EFBO757017.json
# 2014-12-16
# Saved data to ./matches/match-data/EFBO787669.json
# 2014-12-19
# Saved data to ./matches/match-data/EFBO757038.json
# 2014-12-26
# Saved data to ./matches/match-data/EFBO757039.json
# 2014-12-28
# Saved data to ./matches/match-data/EFBO757062.json
# 2015-01-03
# Saved data to ./matches/match-data/EFBO787749.json
# 2015-01-10
# Saved data to ./matches/match-data/EFBO757082.json
# 2015-01-17
# Saved data to ./matches/match-data/EFBO757097.json
# 2015-01-24
# Saved data to ./matches/match-data/EFBO757109.json
# 2015-01-31
# Saved data to ./matches/match-data/EFBO757115.json
# 2015-02-07
# Saved data to ./matches/match-data/EFBO757133.json
# 2015-02-10
# Saved data to ./matches/match-data/EFBO757143.json
# 2015-02-14
# Saved data to ./matches/match-data/EFBO757158.json
# 2015-02-21
# Saved data to ./matches/match-data/EFBO757170.json
# 2015-02-24
# Saved data to ./matches/match-data/EFBO757072.json
# 2015-02-28
# Saved data to ./matches/match-data/EFBO757172.json
# 2015-03-03
# Saved data to ./matches/match-data/EFBO757194.json
# 2015-03-07
# Saved data to ./matches/match-data/EFBO757206.json
# 2015-03-14
# Saved data to ./matches/match-data/EFBO757214.json
# 2015-03-17
# Saved data to ./matches/match-data/EFBO757220.json
# 2015-03-21
# Saved data to ./matches/match-data/EFBO757242.json
# 2015-03-28
# Saved data to ./matches/match-data/EFBO757254.json
# 2015-04-03
# Saved data to ./matches/match-data/EFBO757264.json
# 2015-04-06
# Saved data to ./matches/match-data/EFBO757278.json
# 2015-04-11
# Saved data to ./matches/match-data/EFBO757287.json
# 2015-04-14
# Saved data to ./matches/match-data/EFBO757296.json
# 2015-04-18
# Saved data to ./matches/match-data/EFBO757314.json
# 2015-04-25
# Saved data to ./matches/match-data/EFBO757322.json
# 2015-05-02
# Saved data to ./matches/match-data/EFBO757338.json
# 2015-08-08
# Saved data to ./matches/match-data/EFBO814346.json
# 2015-08-11
# Saved data to ./matches/match-data/EFBO814358.json
# 2015-08-15
# Saved data to ./matches/match-data/EFBO814370.json
# 2015-08-18
# Saved data to ./matches/match-data/EFBO814376.json
# 2015-08-22
# Saved data to ./matches/match-data/EFBO814387.json
# 2015-08-29
# Saved data to ./matches/match-data/EFBO814406.json
# 2015-08-31
# Saved data to ./matches/match-data/EFBO814414.json
# 2015-09-05
# Saved data to ./matches/match-data/EFBO814429.json
# 2015-09-12
# Saved data to ./matches/match-data/EFBO814436.json
# 2015-09-15
# Saved data to ./matches/match-data/EFBO814453.json
# 2015-09-18
# Saved data to ./matches/match-data/EFBO814465.json
# 2015-09-22
# Saved data to ./matches/match-data/EFBO814468.json
# 2015-09-26
# Saved data to ./matches/match-data/EFBO814490.json
# 2015-10-03
# Saved data to ./matches/match-data/EFBO814496.json
# 2015-10-06
# Saved data to ./matches/match-data/EFBO814513.json
# 2015-10-10
# Saved data to ./matches/match-data/EFBO814517.json
# 2015-10-13
# Saved data to ./matches/match-data/EFBO814527.json
# 2015-10-17
# Saved data to ./matches/match-data/EFBO814547.json
# 2015-10-24
# Saved data to ./matches/match-data/EFBO837381.json
# 2015-10-27
# Saved data to ./matches/match-data/EFBO837740.json
# 2015-10-31
# Saved data to ./matches/match-data/EFBO814555.json
# 2015-11-14
# Saved data to ./matches/match-data/EFBO814583.json
# 2015-11-21
# Saved data to ./matches/match-data/EFBO814591.json
# 2015-11-24
# Saved data to ./matches/match-data/EFBO814600.json
# 2015-11-28
# Saved data to ./matches/match-data/EFBO814610.json
# 2015-12-05
# Saved data to ./matches/match-data/EFBO814615.json
# 2015-12-12
# Saved data to ./matches/match-data/EFBO838761.json
# 2015-12-19
# Saved data to ./matches/match-data/EFBO814634.json
# 2015-12-26
# Saved data to ./matches/match-data/EFBO814647.json
# 2015-12-28
# Saved data to ./matches/match-data/EFBO814650.json
# 2016-01-02
# Saved data to ./matches/match-data/EFBO814669.json
# 2016-01-09
# Saved data to ./matches/match-data/EFBO814683.json
# 2016-01-23
# Saved data to ./matches/match-data/EFBO814696.json
# 2016-01-30
# Saved data to ./matches/match-data/EFBO814707.json
# 2016-02-06
# Saved data to ./matches/match-data/EFBO814722.json
# 2016-02-13
# Saved data to ./matches/match-data/EFBO814733.json
# 2016-02-20
# Saved data to ./matches/match-data/EFBO814739.json
# 2016-02-28
# Saved data to ./matches/match-data/EFBO814762.json
# 2016-03-05
# Saved data to ./matches/match-data/EFBO814775.json
# 2016-03-08
# Saved data to ./matches/match-data/EFBO814720.json
# 2016-03-12
# Saved data to ./matches/match-data/EFBO814789.json
# 2016-03-19
# Saved data to ./matches/match-data/EFBO814798.json
# 2016-03-25
# Saved data to ./matches/match-data/EFBO814811.json
# 2016-03-28
# Saved data to ./matches/match-data/EFBO814826.json
# 2016-04-02
# Saved data to ./matches/match-data/EFBO814837.json
# 2016-04-09
# Saved data to ./matches/match-data/EFBO814851.json
# 2016-04-16
# Saved data to ./matches/match-data/EFBO814863.json
# 2016-04-23
# Saved data to ./matches/match-data/EFBO814873.json
# 2016-04-30
# Saved data to ./matches/match-data/EFBO814882.json
# 2016-08-06
# Saved data to ./matches/match-data/EFBO864026.json
# 2016-08-09
# Saved data to ./matches/match-data/EFBO864046.json
# 2016-08-13
# Saved data to ./matches/match-data/EFBO864058.json
# 2016-08-16
# Saved data to ./matches/match-data/EFBO864061.json
# 2016-08-20
# Saved data to ./matches/match-data/EFBO864081.json
# 2016-08-27
# Saved data to ./matches/match-data/EFBO864093.json
# 2016-08-29
# Saved data to ./matches/match-data/EFBO864105.json
# 2016-09-03
# Saved data to ./matches/match-data/EFBO864108.json
# 2016-09-10
# Saved data to ./matches/match-data/EFBO864130.json
# 2016-09-13
# Saved data to ./matches/match-data/EFBO864143.json
# 2016-09-17
# Saved data to ./matches/match-data/EFBO864153.json
# 2016-09-24
# Saved data to ./matches/match-data/EFBO864166.json
# 2016-10-01
# Saved data to ./matches/match-data/EFBO864170.json
# 2016-10-01
# Saved data to ./matches/match-data/EFBO864170.json
# 2016-10-04
# Saved data to ./matches/match-data/EFBO864190.json
# 2016-10-08
# Saved data to ./matches/match-data/EFBO864203.json
# 2016-10-15
# Saved data to ./matches/match-data/EFBO890396.json
# 2016-10-22
# Saved data to ./matches/match-data/EFBO864210.json
# 2016-10-25
# Saved data to ./matches/match-data/EFBO864225.json
# 2016-10-29
# Saved data to ./matches/match-data/EFBO864233.json
# 2016-11-12
# Saved data to ./matches/match-data/EFBO864249.json
# 2016-11-19
# Saved data to ./matches/match-data/EFBO864255.json
# 2016-11-22
# Saved data to ./matches/match-data/EFBO864270.json
# 2016-11-26
# Saved data to ./matches/match-data/EFBO864285.json
# 2016-11-29
# Saved data to ./matches/match-data/EFBO864292.json
# 2016-12-03
# Saved data to ./matches/match-data/EFBO864310.json
# 2016-12-10
# Saved data to ./matches/match-data/EFBO897563.json
# 2016-12-17
# Saved data to ./matches/match-data/EFBO864317.json
# 2016-12-26
# Saved data to ./matches/match-data/EFBO864334.json
# 2017-01-01
# Saved data to ./matches/match-data/EFBO864342.json
# 2017-01-01
# Saved data to ./matches/match-data/EFBO864342.json
# 2017-01-14
# Saved data to ./matches/match-data/EFBO898298.json
# 2017-01-28
# Saved data to ./matches/match-data/EFBO864382.json
# 2017-01-31
# Saved data to ./matches/match-data/EFBO864370.json
# 2017-02-04
# Saved data to ./matches/match-data/EFBO902632.json
# 2017-02-08
# Saved data to ./matches/match-data/EFBO906173.json
# 2017-02-11
# Saved data to ./matches/match-data/EFBO864406.json
# 2017-02-18
# Saved data to ./matches/match-data/EFBO864412.json
# 2017-02-21
# Saved data to ./matches/match-data/EFBO864430.json
# 2017-02-25
# Saved data to ./matches/match-data/EFBO906178.json
# 2017-03-03
# Saved data to ./matches/match-data/EFBO864448.json
# 2017-03-07
# Saved data to ./matches/match-data/EFBO864384.json
# 2017-03-11
# Saved data to ./matches/match-data/EFBO909388.json
# 2017-03-14
# Saved data to ./matches/match-data/EFBO864478.json
# 2017-03-18
# Saved data to ./matches/match-data/EFBO909390.json
# 2017-03-21
# Saved data to ./matches/match-data/EFBO864489.json
# 2017-03-25
# Saved data to ./matches/match-data/EFBO864501.json
# 2017-03-28
# Saved data to ./matches/match-data/EFBO864465.json
# 2017-04-01
# Saved data to ./matches/match-data/EFBO864514.json
# 2017-04-01
# Saved data to ./matches/match-data/EFBO864514.json
# 2017-04-04
# Saved data to ./matches/match-data/EFBO864358.json
# 2017-04-08
# Saved data to ./matches/match-data/EFBO864527.json
# 2017-04-11
# Saved data to ./matches/match-data/EFBO864441.json
# 2017-04-14
# Saved data to ./matches/match-data/EFBO864537.json
# 2017-04-17
# Saved data to ./matches/match-data/EFBO864546.json
# 2017-04-22
# Saved data to ./matches/match-data/EFBO864561.json
# 2017-04-29
# Saved data to ./matches/match-data/EFBO864572.json
# 2017-05-03
# Saved data to ./matches/match-data/EFBO914293.json
# 2017-05-06
# Saved data to ./matches/match-data/EFBO914295.json
# 2017-05-14
# Saved data to ./matches/match-data/EFBO914504.json
# 2017-08-05
# Saved data to ./matches/match-data/EFBO931203.json
# 2017-08-08
# Saved data to ./matches/match-data/EFBO931216.json
# 2017-08-12
# Saved data to ./matches/match-data/EFBO931228.json
# 2017-08-15
# Saved data to ./matches/match-data/EFBO931232.json
# 2017-08-19
# Saved data to ./matches/match-data/EFBO931245.json
# 2017-08-26
# Saved data to ./matches/match-data/EFBO931262.json
# 2017-08-28
# Saved data to ./matches/match-data/EFBO931276.json
# 2017-09-02
# Saved data to ./matches/match-data/EFBO931288.json
# 2017-09-09
# Saved data to ./matches/match-data/EFBO931300.json
# 2017-09-12
# Saved data to ./matches/match-data/EFBO931311.json
# 2017-09-16
# Saved data to ./matches/match-data/EFBO931317.json
# 2017-09-23
# Saved data to ./matches/match-data/EFBO931336.json
# 2017-09-30
# Saved data to ./matches/match-data/EFBO931337.json
# 2017-10-04
# Saved data to ./matches/match-data/EFBO931355.json
# 2017-10-07
# Saved data to ./matches/match-data/EFBO931369.json
# 2017-10-14
# Saved data to ./matches/match-data/EFBO958531.json
# 2017-10-21
# Saved data to ./matches/match-data/EFBO931373.json
# 2017-10-24
# Saved data to ./matches/match-data/EFBO931396.json
# 2017-10-28
# Saved data to ./matches/match-data/EFBO931405.json
# 2017-11-04
# Saved data to ./matches/match-data/EFBO958964.json
# 2017-11-11
# Saved data to ./matches/match-data/EFBO931415.json
# 2017-11-15
# Saved data to ./matches/match-data/EFBO959938.json
# 2017-11-18
# Saved data to ./matches/match-data/EFBO931424.json
# 2017-11-21
# Saved data to ./matches/match-data/EFBO931439.json
# 2017-11-25
# Saved data to ./matches/match-data/EFBO931451.json
# 2017-12-09
# Saved data to ./matches/match-data/EFBO931480.json
# 2017-12-18
# Saved data to ./matches/match-data/EFBO963374.json
# 2017-12-23
# Saved data to ./matches/match-data/EFBO931490.json
# 2017-12-26
# Saved data to ./matches/match-data/EFBO931499.json
# 2017-12-30
# Saved data to ./matches/match-data/EFBO931516.json
# 2018-01-01
# Saved data to ./matches/match-data/EFBO931521.json
# 2018-01-01
# Saved data to ./matches/match-data/EFBO931521.json
# 2018-01-06
# Saved data to ./matches/match-data/EFBO931533.json
# 2018-01-13
# Saved data to ./matches/match-data/EFBO931466.json
# 2018-01-20
# Saved data to ./matches/match-data/EFBO931552.json
# 2018-01-27
# Saved data to ./matches/match-data/EFBO931559.json
# 2018-02-03
# Saved data to ./matches/match-data/EFBO931571.json
# 2018-02-10
# Saved data to ./matches/match-data/EFBO931583.json
# 2018-02-17
# Saved data to ./matches/match-data/EFBO931595.json
# 2018-02-20
# Saved data to ./matches/match-data/EFBO931607.json
# 2018-02-24
# Saved data to ./matches/match-data/EFBO931620.json
# 2018-03-10
# Saved data to ./matches/match-data/EFBO931638.json
# 2018-03-17
# Saved data to ./matches/match-data/EFBO931649.json
# 2018-03-24
# Saved data to ./matches/match-data/EFBO931672.json
# 2018-04-07
# Saved data to ./matches/match-data/EFBO931699.json
# 2018-04-10
# Saved data to ./matches/match-data/EFBO931631.json
# 2018-04-14
# Saved data to ./matches/match-data/EFBO931719.json
# 2018-04-17
# Saved data to ./matches/match-data/EFBO931676.json
# 2018-04-21
# Saved data to ./matches/match-data/EFBO931728.json
# 2018-04-24
# Saved data to ./matches/match-data/EFBO931694.json
# 2018-04-28
# Saved data to ./matches/match-data/EFBO931743.json
# 2018-05-05
# Saved data to ./matches/match-data/EFBO983036.json
# 2018-05-12
# Saved data to ./matches/match-data/EFBO983127.json
# 2018-08-04
# Saved data to ./matches/match-data/EFBO992074.json
# 2018-08-11
# Saved data to ./matches/match-data/EFBO992086.json
# 2018-08-14
# Saved data to ./matches/match-data/EFBO988715.json
# 2018-08-18
# Saved data to ./matches/match-data/EFBO992099.json
# 2018-08-21
# Saved data to ./matches/match-data/EFBO992110.json
# 2018-08-25
# Saved data to ./matches/match-data/EFBO992122.json
# 2018-09-01
# Saved data to ./matches/match-data/EFBO992130.json
# 2018-09-01
# Saved data to ./matches/match-data/EFBO992130.json
# 2018-09-04
# Saved data to ./matches/match-data/EFBO1014828.json
# 2018-09-08
# Saved data to ./matches/match-data/EFBO992146.json
# 2018-09-15
# Saved data to ./matches/match-data/EFBO992148.json
# 2018-09-22
# Saved data to ./matches/match-data/EFBO992170.json
# 2018-09-29
# Saved data to ./matches/match-data/EFBO992179.json
# 2018-10-02
# Saved data to ./matches/match-data/EFBO992195.json
# 2018-10-06
# Saved data to ./matches/match-data/EFBO992203.json
# 2018-10-09
# Saved data to ./matches/match-data/EFBO1014831.json
# 2018-10-12
# Saved data to ./matches/match-data/EFBO992219.json
# 2018-10-20
# Saved data to ./matches/match-data/EFBO992231.json
# 2018-10-23
# Saved data to ./matches/match-data/EFBO992234.json
# 2018-10-27
# Saved data to ./matches/match-data/EFBO992255.json
# 2018-10-30
# Saved data to ./matches/match-data/EFBO1014833.json
# 2018-11-03
# Saved data to ./matches/match-data/EFBO992267.json
# 2018-11-10
# Saved data to ./matches/match-data/EFBO1032591.json
# 2018-11-17
# Saved data to ./matches/match-data/EFBO992269.json
# 2018-11-20
# Saved data to ./matches/match-data/EFBO1033275.json
# 2018-11-24
# Saved data to ./matches/match-data/EFBO992291.json
# 2018-11-27
# Saved data to ./matches/match-data/EFBO992296.json
# 2018-12-02
# Saved data to ./matches/match-data/EFBO1033528.json
# 2018-12-08
# Saved data to ./matches/match-data/EFBO992314.json
# 2018-12-15
# Saved data to ./matches/match-data/EFBO992325.json
# 2018-12-17
# Saved data to ./matches/match-data/EFBO1034643.json
# 2018-12-22
# Saved data to ./matches/match-data/EFBO992328.json
# 2018-12-26
# Saved data to ./matches/match-data/EFBO992351.json
# 2018-12-29
# Saved data to ./matches/match-data/EFBO992363.json
# 2019-01-01
# Saved data to ./matches/match-data/EFBO992369.json
# 2019-01-01
# Saved data to ./matches/match-data/EFBO992369.json
# 2019-01-04
# Saved data to ./matches/match-data/EFBO1034933.json
# 2019-01-12
# Saved data to ./matches/match-data/EFBO992389.json
# 2019-01-19
# Saved data to ./matches/match-data/EFBO992410.json
# 2019-01-26
# Saved data to ./matches/match-data/EFBO992417.json
# 2019-02-05
# Saved data to ./matches/match-data/EFBO992386.json
# 2019-02-09
# Saved data to ./matches/match-data/EFBO992446.json
# 2019-02-16
# Saved data to ./matches/match-data/EFBO992448.json
# 2019-02-19
# Saved data to ./matches/match-data/EFBO992433.json
# 2019-02-23
# Saved data to ./matches/match-data/EFBO992470.json
# 2019-03-02
# Saved data to ./matches/match-data/EFBO992474.json
# 2019-03-08
# Saved data to ./matches/match-data/EFBO992496.json
# 2019-03-12
# Saved data to ./matches/match-data/EFBO992507.json
# 2019-03-23
# Saved data to ./matches/match-data/EFBO992522.json
# 2019-03-30
# Saved data to ./matches/match-data/EFBO992542.json
# 2019-04-02
# Saved data to ./matches/match-data/EFBO992517.json
# 2019-04-06
# Saved data to ./matches/match-data/EFBO992552.json
# 2019-04-13
# Saved data to ./matches/match-data/EFBO992566.json
# 2019-04-19
# Saved data to ./matches/match-data/EFBO992579.json
# 2019-04-22
# Saved data to ./matches/match-data/EFBO992584.json
# 2019-04-30
# Saved data to ./matches/match-data/EFBO992603.json
# 2019-05-04
# Saved data to ./matches/match-data/EFBO992605.json
# 2019-05-10
# Saved data to ./matches/match-data/EFBO1056735.json
# 2019-05-13
# Saved data to ./matches/match-data/EFBO1056737.json
# 2019-05-25
# Saved data to ./matches/match-data/EFBO1057386.json
# 2019-08-03
# Saved data to ./matches/match-data/EFBO1064352.json
# 2019-08-10
# Saved data to ./matches/match-data/EFBO1064362.json
# 2019-08-13
# Saved data to ./matches/match-data/EFBO1065632.json
# 2019-08-17
# Saved data to ./matches/match-data/EFBO1064376.json
# 2019-08-20
# Saved data to ./matches/match-data/EFBO1064380.json
# 2019-08-31
# Saved data to ./matches/match-data/EFBO1064412.json
# 2019-09-07
# Saved data to ./matches/match-data/EFBO1064424.json
# 2019-09-14
# Saved data to ./matches/match-data/EFBO1064434.json
# 2019-09-17
# Saved data to ./matches/match-data/EFBO1064448.json
# 2019-09-21
# Saved data to ./matches/match-data/EFBO1064460.json
# 2019-09-28
# Saved data to ./matches/match-data/EFBO1064466.json
# 2019-10-05
# Saved data to ./matches/match-data/EFBO1064484.json
# 2019-10-08
# Saved data to ./matches/match-data/EFBO1087910.json
# 2019-10-13
# Saved data to ./matches/match-data/EFBO1064489.json
# 2019-10-18
# Saved data to ./matches/match-data/EFBO1064508.json
# 2019-10-22
# Saved data to ./matches/match-data/EFBO1064520.json
# 2019-11-02
# Saved data to ./matches/match-data/EFBO1064541.json
# 2019-11-09
# Saved data to ./matches/match-data/EFBO2033344.json
# 2019-11-12
# Saved data to ./matches/match-data/EFBO1087533.json
# 2019-11-17
# Saved data to ./matches/match-data/EFBO1064557.json
# 2019-11-20
# Saved data to ./matches/match-data/EFBO2040827.json
# 2019-11-23
# Saved data to ./matches/match-data/EFBO1064560.json
# 2019-12-01
# Saved data to ./matches/match-data/EFBO2040878.json
# 2019-12-01
# Saved data to ./matches/match-data/EFBO2040878.json
# 2019-12-04
# Saved data to ./matches/match-data/EFBO2041445.json
# 2019-12-07
# Saved data to ./matches/match-data/EFBO1064581.json
# 2019-12-14
# Saved data to ./matches/match-data/EFBO1064586.json
# 2019-12-21
# Saved data to ./matches/match-data/EFBO1064605.json
# 2019-12-26
# Saved data to ./matches/match-data/EFBO1064608.json
# 2019-12-29
# Saved data to ./matches/match-data/EFBO1064628.json
# 2020-01-01
# Saved data to ./matches/match-data/EFBO1064640.json
# 2020-01-01
# Saved data to ./matches/match-data/EFBO1064640.json
# 2020-01-04
# Saved data to ./matches/match-data/EFBO2042067.json
# 2020-01-07
# Saved data to ./matches/match-data/EFBO2042853.json
# 2020-01-11
# Saved data to ./matches/match-data/EFBO1064664.json
# 2020-01-18
# Saved data to ./matches/match-data/EFBO1064676.json
# 2020-01-23
# Saved data to ./matches/match-data/EFBO2048116.json
# 2020-01-26
# Saved data to ./matches/match-data/EFBO2048316.json
# 2020-01-29
# Saved data to ./matches/match-data/EFBO1064700.json
# 2020-02-01
# Saved data to ./matches/match-data/EFBO1064703.json
# 2020-02-01
# Saved data to ./matches/match-data/EFBO1064703.json
# 2020-02-04
# Saved data to ./matches/match-data/EFBO1064533.json
# 2020-02-08
# Saved data to ./matches/match-data/EFBO1064724.json
# 2020-02-11
# Saved data to ./matches/match-data/EFBO1064736.json
# 2020-02-22
# Saved data to ./matches/match-data/EFBO1064761.json
# 2020-02-25
# Saved data to ./matches/match-data/EFBO1064651.json
# 2020-03-07
# Saved data to ./matches/match-data/EFBO1064775.json
# 2020-03-10
# Saved data to ./matches/match-data/EFBO1064678.json
# 2020-09-05
# Saved data to ./matches/match-data/EFBO2127743.json
# 2020-09-08
# Saved data to ./matches/match-data/EFBO2128099.json
# 2020-09-12
# Saved data to ./matches/match-data/EFBO2130365.json
# 2020-09-19
# Saved data to ./matches/match-data/EFBO2130383.json
# 2020-09-26
# Saved data to ./matches/match-data/EFBO2130387.json
# 2020-09-29
# Saved data to ./matches/match-data/EFBO2128103.json
# 2020-10-03
# Saved data to ./matches/match-data/EFBO2130407.json
# 2020-10-10
# Saved data to ./matches/match-data/EFBO2130416.json
# 2020-10-17
# Saved data to ./matches/match-data/EFBO2130427.json
# 2020-10-20
# Saved data to ./matches/match-data/EFBO2130443.json
# 2020-10-24
# Saved data to ./matches/match-data/EFBO2130455.json
# 2020-10-27
# Saved data to ./matches/match-data/EFBO2130458.json
# 2020-10-31
# Saved data to ./matches/match-data/EFBO2130479.json
# 2020-11-03
# Saved data to ./matches/match-data/EFBO2130487.json
# 2020-11-07
# Saved data to ./matches/match-data/EFBO2173623.json
# 2020-11-11
# Saved data to ./matches/match-data/EFBO2128104.json
# 2020-11-14
# Saved data to ./matches/match-data/EFBO2130502.json
# 2020-11-21
# Saved data to ./matches/match-data/EFBO2130515.json
# 2020-11-24
# Saved data to ./matches/match-data/EFBO2130527.json
# 2020-11-27
# Saved data to ./matches/match-data/EFBO2174987.json
# 2020-12-01
# Saved data to ./matches/match-data/EFBO2130537.json
# 2020-12-01
# Saved data to ./matches/match-data/EFBO2130537.json
# 2020-12-05
# Saved data to ./matches/match-data/EFBO2130551.json
# 2020-12-08
# Saved data to ./matches/match-data/EFBO2176414.json
# 2020-12-12
# Saved data to ./matches/match-data/EFBO2130554.json
# 2020-12-19
# Saved data to ./matches/match-data/EFBO2130577.json
# 2020-12-26
# Saved data to ./matches/match-data/EFBO2130599.json
# 2020-12-29
# Saved data to ./matches/match-data/EFBO2130600.json
# 2021-01-10
# Saved data to ./matches/match-data/EFBO2177561.json
# 2021-01-13
# Saved data to ./matches/match-data/EFBO2181192.json
# 2021-01-16
# Saved data to ./matches/match-data/EFBO2130646.json
# 2021-01-19
# Saved data to ./matches/match-data/EFBO2130635.json
# 2021-01-23
# Saved data to ./matches/match-data/EFBO2130659.json
# 2021-01-26
# Saved data to ./matches/match-data/EFBO2130671.json
# 2021-01-30
# Saved data to ./matches/match-data/EFBO2130680.json
# 2021-02-02
# Saved data to ./matches/match-data/EFBO2187327.json
# 2021-02-06
# Saved data to ./matches/match-data/EFBO2130695.json
# 2021-02-09
# Saved data to ./matches/match-data/EFBO2130575.json
# 2021-02-16
# Saved data to ./matches/match-data/EFBO2189920.json
# 2021-02-20
# Saved data to ./matches/match-data/EFBO2130719.json
# 2021-02-23
# Saved data to ./matches/match-data/EFBO2130723.json
# 2021-02-27
# Saved data to ./matches/match-data/EFBO2130737.json
# 2021-03-02
# Saved data to ./matches/match-data/EFBO2130755.json
# 2021-03-06
# Saved data to ./matches/match-data/EFBO2130767.json
# 2021-03-09
# Saved data to ./matches/match-data/EFBO2130778.json
# 2021-03-14
# Saved data to ./matches/match-data/EFBO2191510.json
# 2021-03-17
# Saved data to ./matches/match-data/EFBO2130702.json
# 2021-03-20
# Saved data to ./matches/match-data/EFBO2130803.json
# 2021-03-23
# Saved data to ./matches/match-data/EFBO2130615.json
# 2021-03-27
# Saved data to ./matches/match-data/EFBO2130815.json
# 2021-04-02
# Saved data to ./matches/match-data/EFBO2130820.json
# 2021-04-05
# Saved data to ./matches/match-data/EFBO2130839.json
# 2021-04-10
# Saved data to ./matches/match-data/EFBO2130849.json
# 2021-04-13
# Saved data to ./matches/match-data/EFBO2130791.json
# 2021-04-17
# Saved data to ./matches/match-data/EFBO2130863.json
# 2021-04-20
# Saved data to ./matches/match-data/EFBO2130866.json
# 2021-04-24
# Saved data to ./matches/match-data/EFBO2130887.json
# 2021-05-01
# Saved data to ./matches/match-data/EFBO2130892.json
# 2021-05-01
# Saved data to ./matches/match-data/EFBO2130892.json
# 2021-05-08
# Saved data to ./matches/match-data/EFBO2130911.json
# 2021-05-20
# Saved data to ./matches/match-data/EFBO2205590.json
# 2021-05-23
# Saved data to ./matches/match-data/EFBO2205591.json
# 2021-08-07
# Saved data to ./matches/match-data/EFBO2213991.json
# 2021-08-10
# Saved data to ./matches/match-data/EFBO2214977.json
# 2021-08-14
# Saved data to ./matches/match-data/EFBO2213999.json
# 2021-08-17
# Saved data to ./matches/match-data/EFBO2214014.json
# 2021-08-21
# Saved data to ./matches/match-data/EFBO2214027.json
# 2021-08-28
# Saved data to ./matches/match-data/EFBO2214036.json
# 2021-09-04
# Saved data to ./matches/match-data/EFBO2214051.json
# 2021-09-11
# Saved data to ./matches/match-data/EFBO2214058.json
# 2021-09-14
# Saved data to ./matches/match-data/EFBO2229418.json
# 2021-09-18
# Saved data to ./matches/match-data/EFBO2214075.json
# 2021-09-25
# Saved data to ./matches/match-data/EFBO2214078.json
# 2021-10-02
# Saved data to ./matches/match-data/EFBO2214099.json
# 2021-10-05
# Saved data to ./matches/match-data/EFBO2229420.json
# 2021-10-08
# Saved data to ./matches/match-data/EFBO2214110.json
# 2021-10-16
# Saved data to ./matches/match-data/EFBO2214113.json
# 2021-10-19
# Saved data to ./matches/match-data/EFBO2214128.json
# 2021-10-23
# Saved data to ./matches/match-data/EFBO2214146.json
# 2021-10-30
# Saved data to ./matches/match-data/EFBO2214154.json
# 2021-11-06
# Saved data to ./matches/match-data/EFBO2257477.json
# 2021-11-09
# Saved data to ./matches/match-data/EFBO2229424.json
# 2021-11-13
# Saved data to ./matches/match-data/EFBO2214170.json
# 2021-11-20
# Saved data to ./matches/match-data/EFBO2214174.json
# 2021-11-23
# Saved data to ./matches/match-data/EFBO2214195.json
# 2021-12-04
# Saved data to ./matches/match-data/EFBO2258702.json
# 2021-12-07
# Saved data to ./matches/match-data/EFBO2214217.json
# 2021-12-11
# Saved data to ./matches/match-data/EFBO2214223.json
# 2021-12-18
# Saved data to ./matches/match-data/EFBO2214243.json
# 2021-12-21
# Saved data to ./matches/match-data/EFBO2258843.json
# 2021-12-26
# Saved data to ./matches/match-data/EFBO2214255.json
# 2022-01-08
# Saved data to ./matches/match-data/EFBO2214291.json
# 2022-01-11
# Saved data to ./matches/match-data/EFBO2214275.json
# 2022-01-15
# Saved data to ./matches/match-data/EFBO2214303.json
# 2022-01-22
# Saved data to ./matches/match-data/EFBO2214305.json
# 2022-01-29
# Saved data to ./matches/match-data/EFBO2214327.json
# 2022-02-01
# Saved data to ./matches/match-data/EFBO2214207.json
# 2022-02-01
# Saved data to ./matches/match-data/EFBO2214207.json
# 2022-02-05
# Saved data to ./matches/match-data/EFBO2214328.json
# 2022-02-08
# Saved data to ./matches/match-data/EFBO2214351.json
# 2022-02-12
# Saved data to ./matches/match-data/EFBO2214363.json
# 2022-02-15
# Saved data to ./matches/match-data/EFBO2214260.json
# 2022-02-19
# Saved data to ./matches/match-data/EFBO2214375.json
# 2022-02-26
# Saved data to ./matches/match-data/EFBO2214382.json
# 2022-03-05
# Saved data to ./matches/match-data/EFBO2214396.json
# 2022-03-11
# Saved data to ./matches/match-data/EFBO2214410.json
# 2022-03-15
# Saved data to ./matches/match-data/EFBO2214422.json
# 2022-03-19
# Saved data to ./matches/match-data/EFBO2214435.json
# 2022-03-26
# Saved data to ./matches/match-data/EFBO2214438.json
# 2022-04-02
# Saved data to ./matches/match-data/EFBO2214458.json
# 2022-04-09
# Saved data to ./matches/match-data/EFBO2214471.json
# 2022-04-15
# Saved data to ./matches/match-data/EFBO2214473.json
# 2022-04-18
# Saved data to ./matches/match-data/EFBO2214495.json
# 2022-04-23
# Saved data to ./matches/match-data/EFBO2214506.json
# 2022-04-30
# Saved data to ./matches/match-data/EFBO2214519.json
# 2022-05-07
# Saved data to ./matches/match-data/EFBO2214526.json
# 2022-07-30
# Saved data to ./matches/match-data/EFBO2300834.json
# 2022-08-06
# Saved data to ./matches/match-data/EFBO2300844.json
# 2022-08-09
# Saved data to ./matches/match-data/EFBO2301560.json
# 2022-08-13
# Saved data to ./matches/match-data/EFBO2300858.json
# 2022-08-16
# Saved data to ./matches/match-data/EFBO2300867.json
# 2022-08-20
# Saved data to ./matches/match-data/EFBO2300881.json
# 2022-08-24
# Saved data to ./matches/match-data/EFBO2324425.json
# 2022-08-27
# Saved data to ./matches/match-data/EFBO2300894.json
# 2022-09-03
# Saved data to ./matches/match-data/EFBO2300902.json
# 2022-09-13
# Saved data to ./matches/match-data/EFBO2300930.json
# 2022-09-17
# Saved data to ./matches/match-data/EFBO2300941.json
# 2022-09-20
# Saved data to ./matches/match-data/EFBO2307409.json
# 2022-09-24
# Saved data to ./matches/match-data/EFBO2300955.json
# 2022-10-01
# Saved data to ./matches/match-data/EFBO2300967.json
# 2022-10-01
# Saved data to ./matches/match-data/EFBO2300967.json
# 2022-10-04
# Saved data to ./matches/match-data/EFBO2307407.json
# 2022-10-08
# Saved data to ./matches/match-data/EFBO2300978.json
# 2022-10-14
# Saved data to ./matches/match-data/EFBO2300991.json
# 2022-10-18
# Saved data to ./matches/match-data/EFBO2307410.json
# 2022-10-22
# Saved data to ./matches/match-data/EFBO2300997.json
# 2022-10-25
# Saved data to ./matches/match-data/EFBO2301014.json
# 2022-10-29
# Saved data to ./matches/match-data/EFBO2301026.json
# 2022-11-01
# Saved data to ./matches/match-data/EFBO2300918.json
# 2022-11-01
# Saved data to ./matches/match-data/EFBO2300918.json
# 2022-11-05
# Saved data to ./matches/match-data/EFBO2333856.json
# 2022-11-12
# Saved data to ./matches/match-data/EFBO2301039.json
# 2022-11-19
# Saved data to ./matches/match-data/EFBO2301050.json
# 2022-11-22
# Saved data to ./matches/match-data/EFBO2336653.json
# 2022-12-03
# Saved data to ./matches/match-data/EFBO2301061.json
# 2022-12-10
# Saved data to ./matches/match-data/EFBO2301068.json
# 2022-12-26
# Saved data to ./matches/match-data/EFBO2301099.json
# 2022-12-29
# Saved data to ./matches/match-data/EFBO2301100.json
# 2023-01-01
# Saved data to ./matches/match-data/EFBO2301115.json
# 2023-01-01
# Saved data to ./matches/match-data/EFBO2301115.json
# 2023-01-07
# Saved data to ./matches/match-data/EFBO2301135.json
# 2023-01-14
# Saved data to ./matches/match-data/EFBO2301147.json
# 2023-01-28
# Saved data to ./matches/match-data/EFBO2301170.json
# 2023-02-04
# Saved data to ./matches/match-data/EFBO2301182.json
# 2023-02-07
# Saved data to ./matches/match-data/EFBO2301152.json
# 2023-02-11
# Saved data to ./matches/match-data/EFBO2301194.json
# 2023-02-14
# Saved data to ./matches/match-data/EFBO2301196.json
# 2023-02-18
# Saved data to ./matches/match-data/EFBO2301218.json
# 2023-02-25
# Saved data to ./matches/match-data/EFBO2301230.json
# 2023-02-28
# Saved data to ./matches/match-data/EFBO2301086.json
# 2023-03-04
# Saved data to ./matches/match-data/EFBO2301242.json
# 2023-03-11
# Saved data to ./matches/match-data/EFBO2301249.json
# 2023-03-18
# Saved data to ./matches/match-data/EFBO2301266.json
# 2023-03-25
# Saved data to ./matches/match-data/EFBO2301269.json
# 2023-03-31
# Saved data to ./matches/match-data/EFBO2301290.json
# 2023-04-07
# Saved data to ./matches/match-data/EFBO2301292.json
# 2023-04-10
# Saved data to ./matches/match-data/EFBO2301314.json
# 2023-04-15
# Saved data to ./matches/match-data/EFBO2301317.json
# 2023-04-18
# Saved data to ./matches/match-data/EFBO2301335.json
# 2023-04-22
# Saved data to ./matches/match-data/EFBO2301350.json
# 2023-04-29
# Saved data to ./matches/match-data/EFBO2301352.json
# 2023-05-08
# Saved data to ./matches/match-data/EFBO2301374.json
# 2023-08-05
# Saved data to ./matches/match-data/EFBO2371632.json

# %%
def insert_round_no(cup_stage):
    if cup_stage is None:
        return None
    elif " FINAL" in cup_stage.upper():
        return "F"
    elif cup_stage.upper() in ["PLAY-OFFS", "SEMI-FINALS"]:
        return "SF"
    elif "QUARTER-FINALS" in cup_stage.upper():
        return "QF"
    elif "FIFTH ROUND" in cup_stage.upper():
        return "5"
    elif "FOURTH ROUND" in cup_stage.upper():
        return "4"
    elif "THIRD ROUND" in cup_stage.upper():
        return "3"
    elif "SECOND ROUND" in cup_stage.upper():
        return "2"
    elif "FIRST ROUND" in cup_stage.upper():
        return "1"
    elif "GROUP" in cup_stage.upper():
        return "G"
    else:
        return None

matches_df["cup_round"] = matches_df.cup_stage.apply(insert_round_no)
matches_df[~matches_df.cup_stage.isna()][["cup_stage", "cup_round"]].head(3)
# Out:
#             cup_stage cup_round
# 372    Play-off Final         F
# 381  Northern Group D         G
# 388  Northern Group D         G

# %%
matches_df.competition = matches_df.competition.str.replace("Sky Bet League", "League").str.replace("Vanarama National", "National")

# %%
generic_comps_map = {
        "Carabao Cup": "League Cup",
        "FA Cup Qualifying": "FA Cup Qualifying",
        "Isuzu FA Trophy": "FA Trophy",
        "League One": "Football League",
        "League Two": "Football League",
        "National League": "Non-League",
        "Papa John's Trophy": "Associate Members' Cup",
        "The Emirates FA Cup": "FA Cup"
    }
matches_df['generic_comp'] = matches_df.competition.map(generic_comps_map)

matches_df[["competition", "generic_comp"]].drop_duplicates().sort_values("competition")
# Out:
#              competition            generic_comp
# 102          Carabao Cup              League Cup
# 229    FA Cup Qualifying       FA Cup Qualifying
# 237      Isuzu FA Trophy               FA Trophy
# 0             League One         Football League
# 156           League Two         Football League
# 211      National League              Non-League
# 5     Papa John's Trophy  Associate Members' Cup
# 69   The Emirates FA Cup                  FA Cup

# %%
import json
import pandas as pd
import requests
import glob
import time

matches = sorted(glob.glob("./matches/match-data/*.json"))

attendances = []
for match in matches:
    event_id = match.replace("./matches/match-data/", "").replace(".json", "")

    lineup_url = f"https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/{event_id}/version/1.0.8"
    # print(lineup_url)

    r = requests.get(lineup_url)
    time.sleep(0.2)

    try:
        data = r.json()

        if "attendance" in data["meta"]:
            attendance = data["meta"]["attendance"].replace(",", "")
        else:
            attendance = None
            print(f"Attendance not found at {lineup_url}")
        if "referee" in data["meta"]:
            referee = data["meta"]["referee"].replace(",", "")
        else:
            referee = None
            print(f"Referee not found at {lineup_url}")

        attendances.append({
            "event_id": event_id,
            "attendance": attendance,
            "referee": referee
        })
    except json.JSONDecodeError:
        print(f"JSONDecodeError at {lineup_url}")
# Out:
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2127743/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2128099/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2128103/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2128104/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130365/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130383/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130387/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130407/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130416/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130427/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130443/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130455/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130458/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130479/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130487/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130502/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130515/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130527/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130537/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130575/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130577/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130615/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130635/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130646/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130659/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130671/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130680/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130695/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130702/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130719/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130723/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130737/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130755/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130767/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130778/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130791/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130803/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130815/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130820/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130839/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130849/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130863/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130866/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130887/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130892/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2130911/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2173623/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2174987/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2176414/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2177561/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2181192/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2187327/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2189920/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2191510/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2205590/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2214146/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2214243/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2214255/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2214382/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO2258843/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361411/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361420/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361433/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361447/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361451/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361471/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361471/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361479/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361495/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361507/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361518/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361531/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361531/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361537/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361555/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361569/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361574/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361589/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361605/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361605/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361614/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361623/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361638/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361653/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361662/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361662/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361674/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361688/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361699/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361713/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361714/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361735/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361749/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361759/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361764/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361764/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361783/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361793/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361800/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361819/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361831/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361844/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361855/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361866/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361871/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361890/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361901/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361915/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361929/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361933/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO361953/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO381822/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO419418/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO420035/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443518/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443554/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443736/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443759/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443796/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443808/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443844/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443845/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443868/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443928/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443988/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO443999/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO444036/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO444045/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO444060/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO472824/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO481014/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO695904/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814468/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814496/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814527/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814610/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814634/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814669/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814696/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO814873/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO837381/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO837381/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO837740/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO838761/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO838761/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO864026/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO864046/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO864203/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO864501/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO890396/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO897563/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO898298/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO902632/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO906173/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO906178/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO909388/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO909388/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO909390/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO909390/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO914295/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931216/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931228/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931262/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931300/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931396/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931451/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931480/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO931583/version/1.0.8
# JSONDecodeError at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO958531/version/1.0.8
# Attendance not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO963374/version/1.0.8
# Referee not found at https://push.api.bbci.co.uk/data/bbc-morph-sport-football-team-lineups-data/event/EFBO963374/version/1.0.8

# %%
attendances = pd.DataFrame(attendances)
attendances.head(3)
# Out:
#       event_id attendance           referee
# 0  EFBO1014828       2174  Graham Salisbury
# 1  EFBO1014831       1379      Peter Wright
# 2  EFBO1014833        747      Paul Marsden

# %%
import json
import glob
import pandas as pd

matches = sorted(glob.glob("./matches/match-data/*.json"))

game_dates = []
for match in matches:
    event_id = match.replace("./matches/match-data/", "").replace(".json", "")

    with open(match) as f:
        data = f.read()

    data = json.loads(data)

    # match_key = next(iter(data["tournamentDatesWithEvents"]))

    game_date = data["events"][0]["startTime"][:10]

    game_dates.append({
        "event_id": event_id,
        "game_date": game_date
    })

game_dates = pd.DataFrame(game_dates).drop_duplicates()

# %%
game_dates
# Out:
#         event_id   game_date
# 0    EFBO1014828  2018-09-04
# 1    EFBO1014831  2018-10-09
# 2    EFBO1014833  2018-10-30
# 3    EFBO1032591  2018-11-10
# 4    EFBO1033275  2018-11-20
# ..           ...         ...
# 626   EFBO992566  2019-04-13
# 627   EFBO992579  2019-04-19
# 628   EFBO992584  2019-04-22
# 629   EFBO992603  2019-04-30
# 630   EFBO992605  2019-05-04
#
# [631 rows x 2 columns]

# %%
atts_and_refs = game_dates.merge(attendances, on="event_id", how="left")

# %%
all_apps_df = all_apps_df.merge(game_dates, on = "event_id", how = "left")
column = all_apps_df.pop("game_date")
all_apps_df.insert(0, "game_date", column)
all_apps_df = all_apps_df.drop(columns = ["event_id"])

all_subs_df = all_subs_df.merge(game_dates, on = "event_id", how = "left")
column = all_subs_df.pop("game_date")
all_subs_df.insert(0, "game_date", column)
all_subs_df = all_subs_df.drop(columns = ["event_id"])

all_sub_mins_df = all_sub_mins_df.merge(game_dates, on = "event_id", how = "left")
column = all_sub_mins_df.pop("game_date")
all_sub_mins_df.insert(0, "game_date", column)
all_sub_mins_df = all_sub_mins_df.drop(columns = ["event_id"])

all_yellows_df = all_yellows_df.merge(game_dates, on = "event_id", how = "left")
column = all_yellows_df.pop("game_date")
all_yellows_df.insert(0, "game_date", column)
all_yellows_df = all_yellows_df.drop(columns = ["event_id"])

all_reds_df = all_reds_df.merge(game_dates, on = "event_id", how = "left")
column = all_reds_df.pop("game_date")
all_reds_df.insert(0, "game_date", column)
all_reds_df = all_reds_df.drop(columns = ["event_id"])

# %%
all_apps_df.query("~game_date.isna()").to_csv("./processed-csvs/bbc_api_apps.csv", index = False)
all_subs_df.query("~game_date.isna()").to_csv("./processed-csvs/bbc_api_subs.csv", index = False)
all_sub_mins_df.query("~game_date.isna()").to_csv("./processed-csvs/bbc_api_sub_mins.csv", index = False)
all_yellows_df.query("~game_date.isna()").to_csv("./processed-csvs/bbc_api_yellows.csv", index = False)
all_reds_df.query("~game_date.isna()").to_csv("./processed-csvs/bbc_api_reds.csv", index = False)
